# %%
# !pip install -q tqdm

# %%
import pandas as pd
import numpy as np
import tqdm
from lightgbm import LGBMClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h1> Read Data </h1>

# %%
X_train = pd.read_csv('train_bert_embedding_w_jobid.csv')
X_test = pd.read_csv('test_bert_embedding_w_jobid.csv')

# %%
X_train = X_train.drop(['job_id', 'fraudulent'], axis=1)
X_test = X_test.drop(['job_id', 'fraudulent'], axis=1)
y_train = pd.read_csv('train_bert_embedding_w_jobid.csv')['fraudulent']
y_test = pd.read_csv('test_bert_embedding_w_jobid.csv')['fraudulent']

# %%
# Display the first 5 rows of the dataset
X_train.head()
# Out:
#    telecommuting  has_company_logo  has_questions  sentiment score_profile  \
# 0              0                 1              0                   0.9313
# 1              0                 1              0                   0.9618
# 2              0                 1              1                   0.9913
# 3              0                 1              1                   0.9620
# 4              0                 1              1                   0.9753
#
#    sentiment score_requirement  sentiment score_benefits  \
# 0                       0.9929                    0.9716
# 1                       0.9260                    0.0000
# 2                       0.4019                    0.3818
# 3                       0.9657                    0.9081
# 4                       0.7391                    0.9671
#
#    sentiment score_description  department_frequency  department_mean_target  \
# 0                       0.9951              0.000280                0.000000
# 1                       0.9509              0.675685                0.044594
# 2                       0.9426              0.675685                0.044594
# 3                       0.5719              0.000070                0.000000
# 4                       0.9974              0.675685                0.044594
#
#    num_of_nouns_company_profile  ...  requirement759  requirement760  \
# 0                      0.185841  ...       -0.167115       -0.206595
# 1                      0.132743  ...       -0.167115       -0.206595
# 2                      0.207965  ...       -0.167115       -0.206595
# 3                      0.150442  ...       -0.167115       -0.206595
# 4                      0.194690  ...       -0.167115       -0.206595
#
#    requirement761  requirement762  requirement763  requirement764  \
# 0        0.087953       -0.391113        -0.06382       -0.088465
# 1        0.087953       -0.391113        -0.06382       -0.088465
# 2        0.087953       -0.391113        -0.06382       -0.088465
# 3        0.087953       -0.391113        -0.06382       -0.088465
# 4        0.087953       -0.391113        -0.06382       -0.088465
#
#    requirement765  requirement766  requirement767  requirement768
# 0       -0.131694       -0.234339        0.194257       -0.060869
# 1       -0.131694       -0.234339        0.194257       -0.060869
# 2       -0.131694       -0.234339        0.194257       -0.060869
# 3       -0.131694       -0.234339        0.194257       -0.060869
# 4       -0.131694       -0.234339        0.194257       -0.060869
#
# [5 rows x 3146 columns]

# %%
# Display the first 5 rows of the dataset
X_test.head()
# Out:
#    telecommuting  has_company_logo  has_questions  sentiment score_profile  \
# 0              0                 1              0                   0.9856
# 1              0                 1              0                   0.9612
# 2              0                 0              0                   0.0000
# 3              0                 1              1                   0.9934
# 4              0                 1              0                   0.9783
#
#    sentiment score_requirement  sentiment score_benefits  \
# 0                       0.7345                    0.0000
# 1                       0.9819                    0.8462
# 2                       0.0000                    0.0000
# 3                       0.8439                    0.0000
# 4                       0.9618                    0.8885
#
#    sentiment score_description  department_frequency  department_mean_target  \
# 0                       0.6486              0.022301                0.006270
# 1                       0.9957              0.675685                0.044594
# 2                       0.9983              0.675685                0.044594
# 3                       0.0000              0.675685                0.044594
# 4                       0.9896              0.675685                0.044594
#
#    num_of_nouns_company_profile  ...  requirement759  requirement760  \
# 0                      0.123894  ...        0.067283       -0.105608
# 1                      0.123894  ...        0.067283       -0.105608
# 2                      0.000000  ...        0.067283       -0.105608
# 3                      0.234513  ...        0.067283       -0.105608
# 4                      0.079646  ...        0.067283       -0.105608
#
#    requirement761  requirement762  requirement763  requirement764  \
# 0        0.290805       -0.149879       -0.095278       -0.495512
# 1        0.290805       -0.149879       -0.095278       -0.495512
# 2        0.290805       -0.149879       -0.095278       -0.495512
# 3        0.290805       -0.149879       -0.095278       -0.495512
# 4        0.290805       -0.149879       -0.095278       -0.495512
#
#    requirement765  requirement766  requirement767  requirement768
# 0         0.19802       -0.294343       -0.289188        0.094234
# 1         0.19802       -0.294343       -0.289188        0.094234
# 2         0.19802       -0.294343       -0.289188        0.094234
# 3         0.19802       -0.294343       -0.289188        0.094234
# 4         0.19802       -0.294343       -0.289188        0.094234
#
# [5 rows x 3146 columns]

# %% [markdown]
# ###K-Nearest Neighbors (KNN)###

# %%
from sklearn.neighbors import KNeighborsClassifier

# KNN Classifier
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train, y_train)

# Predictions
y_pred_knn = knn_classifier.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_knn)
precision = precision_score(y_test, y_pred_knn)
recall = recall_score(y_test, y_pred_knn)
f1 = f1_score(y_test, y_pred_knn)
print("KNN - Accuracy:", accuracy)
print("KNN - Precision:", precision)
print("KNN - Recall:", recall)
print("KNN - F1:", f1)
# Out:
# KNN - Accuracy: 0.9798657718120806
# KNN - Precision: 0.8707482993197279
# KNN - Recall: 0.7071823204419889
# KNN - F1: 0.7804878048780487

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Randomized search for best hyperparameters

# Create the model
knn = KNeighborsClassifier(p=1)

# Create the random grid
params = {'n_neighbors': [3, 4, 5, 6, 7, 9],
          'weights': ['uniform', 'distance'],
          'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
          'leaf_size': [5, 10, 20, 30, 40]}

# Random search of parameters, using 5 fold cross validation,
# search across 100 different combinations, and use all available cores
knn_random = RandomizedSearchCV(estimator=knn, 
                                param_distributions=params, 
                                n_iter=100, 
                                cv=5, 
                                verbose=3, 
                                random_state=61,
                                n_jobs=-1,
                                scoring='f1')

# Fit the random search model
knn_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# 4069.22s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 4069.23s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 4069.23s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 4069.24s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 4069.24s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 4069.26s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 4069.27s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 4069.28s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 4069.28s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 4069.29s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [CV 4/5] END algorithm=brute, leaf_size=30, n_neighbors=6, weights=uniform;, score=0.648 total time= 2.6min
# [CV 3/5] END algorithm=brute, leaf_size=30, n_neighbors=6, weights=uniform;, score=0.742 total time= 2.6min
# [CV 5/5] END algorithm=brute, leaf_size=30, n_neighbors=6, weights=uniform;, score=0.667 total time= 2.6min
# [CV 2/5] END algorithm=brute, leaf_size=30, n_neighbors=6, weights=uniform;, score=0.649 total time= 2.6min
# [CV 1/5] END algorithm=brute, leaf_size=30, n_neighbors=6, weights=uniform;, score=0.661 total time= 2.6min
# [CV 3/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=6, weights=distance;, score=0.818 total time= 3.5min
# [CV 4/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=6, weights=distance;, score=0.717 total time= 3.6min
# [CV 1/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=6, weights=distance;, score=0.777 total time= 3.7min
# [CV 2/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=6, weights=distance;, score=0.720 total time= 3.8min
# [CV 5/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=6, weights=distance;, score=0.702 total time= 3.8min
# [CV 2/5] END algorithm=brute, leaf_size=20, n_neighbors=4, weights=uniform;, score=0.689 total time= 2.5min
# [CV 1/5] END algorithm=brute, leaf_size=20, n_neighbors=4, weights=uniform;, score=0.715 total time= 2.5min
# [CV 3/5] END algorithm=brute, leaf_size=20, n_neighbors=4, weights=uniform;, score=0.776 total time= 2.5min
# [CV 4/5] END algorithm=brute, leaf_size=20, n_neighbors=4, weights=uniform;, score=0.682 total time= 2.5min
# [CV 5/5] END algorithm=brute, leaf_size=20, n_neighbors=4, weights=uniform;, score=0.688 total time= 2.5min
# [CV 1/5] END algorithm=auto, leaf_size=40, n_neighbors=6, weights=distance;, score=0.777 total time= 2.5min
# [CV 2/5] END algorithm=auto, leaf_size=40, n_neighbors=6, weights=distance;, score=0.720 total time= 2.5min
# [CV 3/5] END algorithm=auto, leaf_size=40, n_neighbors=6, weights=distance;, score=0.818 total time= 2.5min
# [CV 4/5] END algorithm=auto, leaf_size=40, n_neighbors=6, weights=distance;, score=0.717 total time= 2.5min
# [CV 5/5] END algorithm=auto, leaf_size=40, n_neighbors=6, weights=distance;, score=0.702 total time= 2.5min
# [CV 3/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=5, weights=uniform;, score=0.759 total time= 1.9min
# [CV 1/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=5, weights=uniform;, score=0.714 total time= 2.0min
# [CV 4/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=5, weights=uniform;, score=0.698 total time= 2.0min
# [CV 2/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=5, weights=uniform;, score=0.702 total time= 2.1min
# [CV 5/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=5, weights=uniform;, score=0.684 total time= 2.1min
# [CV 3/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=5, weights=uniform;, score=0.759 total time= 3.3min
# [CV 1/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=5, weights=uniform;, score=0.714 total time= 3.5min
# [CV 1/5] END algorithm=auto, leaf_size=10, n_neighbors=9, weights=distance;, score=0.669 total time= 2.5min
# [CV 2/5] END algorithm=auto, leaf_size=10, n_neighbors=9, weights=distance;, score=0.677 total time= 2.5min
# [CV 3/5] END algorithm=auto, leaf_size=10, n_neighbors=9, weights=distance;, score=0.795 total time= 2.5min
# [CV 4/5] END algorithm=auto, leaf_size=10, n_neighbors=9, weights=distance;, score=0.667 total time= 2.5min
# [CV 4/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=5, weights=uniform;, score=0.698 total time= 3.4min
# [CV 5/5] END algorithm=auto, leaf_size=10, n_neighbors=9, weights=distance;, score=0.676 total time= 2.5min
# [CV 2/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=5, weights=uniform;, score=0.702 total time= 3.6min
# [CV 5/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=5, weights=uniform;, score=0.684 total time= 3.6min
# [CV 1/5] END algorithm=auto, leaf_size=20, n_neighbors=7, weights=distance;, score=0.716 total time= 2.6min
# [CV 2/5] END algorithm=auto, leaf_size=20, n_neighbors=7, weights=distance;, score=0.715 total time= 2.6min
# [CV 3/5] END algorithm=auto, leaf_size=20, n_neighbors=7, weights=distance;, score=0.802 total time= 2.6min
# [CV 4/5] END algorithm=auto, leaf_size=20, n_neighbors=7, weights=distance;, score=0.689 total time= 2.6min
# [CV 5/5] END algorithm=auto, leaf_size=20, n_neighbors=7, weights=distance;, score=0.685 total time= 2.6min
# [CV 1/5] END algorithm=brute, leaf_size=30, n_neighbors=9, weights=distance;, score=0.669 total time= 2.6min
# [CV 2/5] END algorithm=brute, leaf_size=30, n_neighbors=9, weights=distance;, score=0.677 total time= 2.6min
# [CV 3/5] END algorithm=brute, leaf_size=30, n_neighbors=9, weights=distance;, score=0.795 total time= 2.6min
# [CV 4/5] END algorithm=brute, leaf_size=30, n_neighbors=9, weights=distance;, score=0.667 total time= 2.6min
# [CV 5/5] END algorithm=brute, leaf_size=30, n_neighbors=9, weights=distance;, score=0.676 total time= 2.6min
# [CV 3/5] END algorithm=kd_tree, leaf_size=40, n_neighbors=5, weights=uniform;, score=0.759 total time= 2.0min
# [CV 1/5] END algorithm=kd_tree, leaf_size=40, n_neighbors=5, weights=uniform;, score=0.714 total time= 2.1min
# [CV 2/5] END algorithm=kd_tree, leaf_size=40, n_neighbors=5, weights=uniform;, score=0.702 total time= 2.1min
# [CV 4/5] END algorithm=kd_tree, leaf_size=40, n_neighbors=5, weights=uniform;, score=0.698 total time= 2.0min
# [CV 5/5] END algorithm=kd_tree, leaf_size=40, n_neighbors=5, weights=uniform;, score=0.684 total time= 2.1min
# [CV 1/5] END algorithm=brute, leaf_size=20, n_neighbors=3, weights=uniform;, score=0.741 total time= 2.5min
# [CV 2/5] END algorithm=brute, leaf_size=20, n_neighbors=3, weights=uniform;, score=0.715 total time= 2.5min
# [CV 4/5] END algorithm=brute, leaf_size=20, n_neighbors=3, weights=uniform;, score=0.731 total time= 2.5min
# [CV 3/5] END algorithm=brute, leaf_size=20, n_neighbors=3, weights=uniform;, score=0.831 total time= 2.5min
# [CV 5/5] END algorithm=brute, leaf_size=20, n_neighbors=3, weights=uniform;, score=0.739 total time= 2.5min
# [CV 1/5] END algorithm=auto, leaf_size=30, n_neighbors=3, weights=distance;, score=0.761 total time= 2.5min
# [CV 2/5] END algorithm=auto, leaf_size=30, n_neighbors=3, weights=distance;, score=0.747 total time= 2.5min
# [CV 3/5] END algorithm=auto, leaf_size=30, n_neighbors=3, weights=distance;, score=0.862 total time= 2.5min
# [CV 4/5] END algorithm=auto, leaf_size=30, n_neighbors=3, weights=distance;, score=0.751 total time= 2.5min
# [CV 5/5] END algorithm=auto, leaf_size=30, n_neighbors=3, weights=distance;, score=0.763 total time= 2.5min
# [CV 2/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=9, weights=distance;, score=0.677 total time= 2.5min
# [CV 1/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=9, weights=distance;, score=0.669 total time= 2.5min
# [CV 4/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=9, weights=distance;, score=0.667 total time= 2.5min
# [CV 3/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=9, weights=distance;, score=0.795 total time= 2.5min
# [CV 5/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=9, weights=distance;, score=0.676 total time= 2.5min
# [CV 3/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=3, weights=distance;, score=0.862 total time= 1.8min
# [CV 1/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=3, weights=distance;, score=0.761 total time= 1.9min
# [CV 2/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=3, weights=distance;, score=0.747 total time= 2.0min
# [CV 4/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=3, weights=distance;, score=0.751 total time= 1.9min
# [CV 5/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=3, weights=distance;, score=0.763 total time= 2.0min
# [CV 1/5] END algorithm=brute, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.596 total time= 2.5min
# [CV 2/5] END algorithm=brute, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.585 total time= 2.5min
# [CV 3/5] END algorithm=brute, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.720 total time= 2.5min
# [CV 4/5] END algorithm=brute, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.640 total time= 2.5min
# [CV 5/5] END algorithm=brute, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.602 total time= 2.5min
# [CV 3/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=3, weights=distance;, score=0.862 total time= 2.1min
# [CV 1/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=3, weights=distance;, score=0.761 total time= 2.3min
# [CV 4/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=3, weights=distance;, score=0.751 total time= 2.2min
# [CV 2/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=3, weights=distance;, score=0.747 total time= 2.3min
# [CV 5/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=3, weights=distance;, score=0.763 total time= 2.3min
# [CV 1/5] END algorithm=brute, leaf_size=10, n_neighbors=6, weights=distance;, score=0.777 total time= 2.5min
# [CV 2/5] END algorithm=brute, leaf_size=10, n_neighbors=6, weights=distance;, score=0.720 total time= 2.5min
# [CV 3/5] END algorithm=brute, leaf_size=10, n_neighbors=6, weights=distance;, score=0.818 total time= 2.5min
# [CV 4/5] END algorithm=brute, leaf_size=10, n_neighbors=6, weights=distance;, score=0.717 total time= 2.5min
# [CV 5/5] END algorithm=brute, leaf_size=10, n_neighbors=6, weights=distance;, score=0.702 total time= 2.6min
# [CV 2/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=3, weights=distance;, score=0.747 total time= 2.3min
# [CV 1/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=3, weights=distance;, score=0.761 total time= 2.3min
# [CV 3/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=3, weights=distance;, score=0.862 total time= 2.3min
# [CV 4/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=3, weights=distance;, score=0.751 total time= 2.3min
# [CV 5/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=3, weights=distance;, score=0.763 total time= 2.3min
# [CV 1/5] END algorithm=brute, leaf_size=40, n_neighbors=5, weights=uniform;, score=0.714 total time= 2.6min
# [CV 2/5] END algorithm=brute, leaf_size=40, n_neighbors=5, weights=uniform;, score=0.702 total time= 2.6min
# [CV 3/5] END algorithm=brute, leaf_size=40, n_neighbors=5, weights=uniform;, score=0.759 total time= 2.6min
# [CV 4/5] END algorithm=brute, leaf_size=40, n_neighbors=5, weights=uniform;, score=0.698 total time= 2.6min
# [CV 5/5] END algorithm=brute, leaf_size=40, n_neighbors=5, weights=uniform;, score=0.684 total time= 2.6min
# [CV 1/5] END algorithm=brute, leaf_size=5, n_neighbors=6, weights=distance;, score=0.777 total time= 2.6min
# [CV 2/5] END algorithm=brute, leaf_size=5, n_neighbors=6, weights=distance;, score=0.720 total time= 2.6min
# [CV 3/5] END algorithm=brute, leaf_size=5, n_neighbors=6, weights=distance;, score=0.818 total time= 2.6min
# [CV 4/5] END algorithm=brute, leaf_size=5, n_neighbors=6, weights=distance;, score=0.717 total time= 2.6min
# [CV 5/5] END algorithm=brute, leaf_size=5, n_neighbors=6, weights=distance;, score=0.702 total time= 2.6min
# [CV 2/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=7, weights=uniform;, score=0.644 total time= 2.5min
# [CV 1/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=7, weights=uniform;, score=0.637 total time= 2.5min
# [CV 3/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=7, weights=uniform;, score=0.737 total time= 2.5min
# [CV 4/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=7, weights=uniform;, score=0.649 total time= 2.5min
# [CV 5/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=7, weights=uniform;, score=0.667 total time= 2.5min
# [CV 1/5] END algorithm=auto, leaf_size=40, n_neighbors=9, weights=uniform;, score=0.596 total time= 2.6min
# [CV 2/5] END algorithm=auto, leaf_size=40, n_neighbors=9, weights=uniform;, score=0.585 total time= 2.6min
# [CV 3/5] END algorithm=auto, leaf_size=40, n_neighbors=9, weights=uniform;, score=0.720 total time= 2.6min
# [CV 4/5] END algorithm=auto, leaf_size=40, n_neighbors=9, weights=uniform;, score=0.640 total time= 2.6min
# [CV 5/5] END algorithm=auto, leaf_size=40, n_neighbors=9, weights=uniform;, score=0.602 total time= 2.6min
# [CV 2/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=5, weights=uniform;, score=0.702 total time= 2.5min
# [CV 1/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=5, weights=uniform;, score=0.714 total time= 2.5min
# [CV 3/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=5, weights=uniform;, score=0.759 total time= 2.5min
# [CV 4/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=5, weights=uniform;, score=0.698 total time= 2.6min
# [CV 5/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=5, weights=uniform;, score=0.684 total time= 2.5min
# [CV 3/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.720 total time= 2.7min
# [CV 1/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.596 total time= 2.9min
# [CV 4/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.640 total time= 2.8min
# [CV 2/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.585 total time= 3.0min
# [CV 5/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.602 total time= 2.9min
# [CV 1/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=6, weights=distance;, score=0.777 total time= 2.1min
# [CV 3/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=6, weights=distance;, score=0.818 total time= 2.0min
# [CV 2/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=6, weights=distance;, score=0.720 total time= 2.1min
# [CV 4/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=6, weights=distance;, score=0.717 total time= 2.1min
# [CV 5/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=6, weights=distance;, score=0.702 total time= 2.2min
# [CV 1/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, weights=distance;, score=0.761 total time= 2.4min
# [CV 2/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, weights=distance;, score=0.747 total time= 2.4min
# [CV 3/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, weights=distance;, score=0.862 total time= 2.4min
# [CV 4/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, weights=distance;, score=0.751 total time= 2.4min
# [CV 5/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, weights=distance;, score=0.763 total time= 2.4min
# [CV 3/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=7, weights=distance;, score=0.802 total time= 3.5min
# [CV 1/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=7, weights=distance;, score=0.716 total time= 3.7min
# [CV 4/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=7, weights=distance;, score=0.689 total time= 3.6min
# [CV 2/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=7, weights=distance;, score=0.715 total time= 3.8min
# [CV 2/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=5, weights=distance;, score=0.731 total time= 2.4min
# [CV 1/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=5, weights=distance;, score=0.794 total time= 2.4min
# [CV 3/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=5, weights=distance;, score=0.816 total time= 2.4min
# [CV 4/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=5, weights=distance;, score=0.723 total time= 2.4min
# [CV 5/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=7, weights=distance;, score=0.685 total time= 3.9min
# [CV 5/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=5, weights=distance;, score=0.716 total time= 2.4min
# [CV 3/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=5, weights=distance;, score=0.816 total time= 1.9min
# [CV 1/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=5, weights=distance;, score=0.794 total time= 2.0min
# [CV 2/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=5, weights=distance;, score=0.731 total time= 2.1min
# [CV 1/5] END algorithm=auto, leaf_size=10, n_neighbors=4, weights=uniform;, score=0.715 total time= 2.5min
# [CV 3/5] END algorithm=auto, leaf_size=10, n_neighbors=4, weights=uniform;, score=0.776 total time= 2.5min
# [CV 2/5] END algorithm=auto, leaf_size=10, n_neighbors=4, weights=uniform;, score=0.689 total time= 2.5min
# [CV 4/5] END algorithm=auto, leaf_size=10, n_neighbors=4, weights=uniform;, score=0.682 total time= 2.5min
# [CV 5/5] END algorithm=auto, leaf_size=10, n_neighbors=4, weights=uniform;, score=0.688 total time= 2.5min
# [CV 4/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=5, weights=distance;, score=0.723 total time= 2.0min
# [CV 5/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=5, weights=distance;, score=0.716 total time= 2.1min
# [CV 1/5] END algorithm=brute, leaf_size=5, n_neighbors=7, weights=uniform;, score=0.637 total time= 2.5min
# [CV 2/5] END algorithm=brute, leaf_size=5, n_neighbors=7, weights=uniform;, score=0.644 total time= 2.5min
# [CV 3/5] END algorithm=brute, leaf_size=5, n_neighbors=7, weights=uniform;, score=0.737 total time= 2.5min
# [CV 1/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=9, weights=distance;, score=0.669 total time= 2.2min
# [CV 3/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=9, weights=distance;, score=0.795 total time= 2.1min
# [CV 4/5] END algorithm=brute, leaf_size=5, n_neighbors=7, weights=uniform;, score=0.649 total time= 2.5min
# [CV 4/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=9, weights=distance;, score=0.667 total time= 2.2min
# [CV 2/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=9, weights=distance;, score=0.677 total time= 2.3min
# [CV 5/5] END algorithm=brute, leaf_size=5, n_neighbors=7, weights=uniform;, score=0.667 total time= 2.5min
# [CV 5/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=9, weights=distance;, score=0.676 total time= 2.3min
# [CV 1/5] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=distance;, score=0.794 total time= 2.5min
# [CV 2/5] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=distance;, score=0.731 total time= 2.5min
# [CV 3/5] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=distance;, score=0.816 total time= 2.5min
# [CV 4/5] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=distance;, score=0.723 total time= 2.5min
# [CV 5/5] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=distance;, score=0.716 total time= 2.5min
# [CV 1/5] END algorithm=brute, leaf_size=10, n_neighbors=5, weights=distance;, score=0.794 total time= 2.5min
# [CV 2/5] END algorithm=brute, leaf_size=10, n_neighbors=5, weights=distance;, score=0.731 total time= 2.5min
# [CV 3/5] END algorithm=brute, leaf_size=10, n_neighbors=5, weights=distance;, score=0.816 total time= 2.5min
# [CV 4/5] END algorithm=brute, leaf_size=10, n_neighbors=5, weights=distance;, score=0.723 total time= 2.5min
# [CV 5/5] END algorithm=brute, leaf_size=10, n_neighbors=5, weights=distance;, score=0.716 total time= 2.5min
# [CV 1/5] END algorithm=brute, leaf_size=20, n_neighbors=5, weights=distance;, score=0.794 total time= 2.5min
# [CV 2/5] END algorithm=brute, leaf_size=20, n_neighbors=5, weights=distance;, score=0.731 total time= 2.5min
# [CV 3/5] END algorithm=brute, leaf_size=20, n_neighbors=5, weights=distance;, score=0.816 total time= 2.5min
# [CV 4/5] END algorithm=brute, leaf_size=20, n_neighbors=5, weights=distance;, score=0.723 total time= 2.5min
# [CV 5/5] END algorithm=brute, leaf_size=20, n_neighbors=5, weights=distance;, score=0.716 total time= 2.5min
# [CV 1/5] END algorithm=auto, leaf_size=30, n_neighbors=7, weights=uniform;, score=0.637 total time= 2.5min
# [CV 2/5] END algorithm=auto, leaf_size=30, n_neighbors=7, weights=uniform;, score=0.644 total time= 2.5min
# [CV 3/5] END algorithm=auto, leaf_size=30, n_neighbors=7, weights=uniform;, score=0.737 total time= 2.5min
# [CV 4/5] END algorithm=auto, leaf_size=30, n_neighbors=7, weights=uniform;, score=0.649 total time= 2.5min
# [CV 5/5] END algorithm=auto, leaf_size=30, n_neighbors=7, weights=uniform;, score=0.667 total time= 2.5min
# [CV 2/5] END algorithm=auto, leaf_size=5, n_neighbors=9, weights=distance;, score=0.677 total time= 2.5min
# [CV 1/5] END algorithm=auto, leaf_size=5, n_neighbors=9, weights=distance;, score=0.669 total time= 2.5min
# [CV 3/5] END algorithm=auto, leaf_size=5, n_neighbors=9, weights=distance;, score=0.795 total time= 2.5min
# [CV 4/5] END algorithm=auto, leaf_size=5, n_neighbors=9, weights=distance;, score=0.667 total time= 2.5min
# [CV 5/5] END algorithm=auto, leaf_size=5, n_neighbors=9, weights=distance;, score=0.676 total time= 2.5min
# [CV 1/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=6, weights=uniform;, score=0.661 total time= 2.5min
# [CV 2/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=6, weights=uniform;, score=0.649 total time= 2.4min
# [CV 3/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=6, weights=uniform;, score=0.742 total time= 2.4min
# [CV 4/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=6, weights=uniform;, score=0.648 total time= 2.5min
# [CV 5/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=6, weights=uniform;, score=0.667 total time= 2.5min
# [CV 1/5] END algorithm=brute, leaf_size=5, n_neighbors=9, weights=distance;, score=0.669 total time= 2.5min
# [CV 2/5] END algorithm=brute, leaf_size=5, n_neighbors=9, weights=distance;, score=0.677 total time= 2.5min
# [CV 3/5] END algorithm=brute, leaf_size=5, n_neighbors=9, weights=distance;, score=0.795 total time= 2.5min
# [CV 4/5] END algorithm=brute, leaf_size=5, n_neighbors=9, weights=distance;, score=0.667 total time= 2.5min
# [CV 2/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.585 total time= 2.5min
# [CV 5/5] END algorithm=brute, leaf_size=5, n_neighbors=9, weights=distance;, score=0.676 total time= 2.5min
# [CV 1/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.596 total time= 2.5min
# [CV 3/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.720 total time= 2.5min
# [CV 4/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.640 total time= 2.5min
# [CV 5/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.602 total time= 2.5min
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3, weights=distance;, score=0.747 total time= 2.3min
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3, weights=distance;, score=0.761 total time= 2.3min
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3, weights=distance;, score=0.862 total time= 2.3min
# [CV 1/5] END algorithm=brute, leaf_size=30, n_neighbors=4, weights=distance;, score=0.773 total time= 2.6min
# [CV 2/5] END algorithm=brute, leaf_size=30, n_neighbors=4, weights=distance;, score=0.744 total time= 2.6min
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3, weights=distance;, score=0.751 total time= 2.3min
# [CV 3/5] END algorithm=brute, leaf_size=30, n_neighbors=4, weights=distance;, score=0.842 total time= 2.6min
# [CV 4/5] END algorithm=brute, leaf_size=30, n_neighbors=4, weights=distance;, score=0.747 total time= 2.6min
# [CV 5/5] END algorithm=brute, leaf_size=30, n_neighbors=4, weights=distance;, score=0.749 total time= 2.6min
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=3, weights=distance;, score=0.763 total time= 2.3min
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5, weights=distance;, score=0.731 total time= 2.3min
# [CV 1/5] END algorithm=brute, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.596 total time= 2.5min
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5, weights=distance;, score=0.794 total time= 2.3min
# [CV 2/5] END algorithm=brute, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.585 total time= 2.5min
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5, weights=distance;, score=0.816 total time= 2.3min
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5, weights=distance;, score=0.723 total time= 2.3min
# [CV 3/5] END algorithm=brute, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.720 total time= 2.5min
# [CV 4/5] END algorithm=brute, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.640 total time= 2.5min
# [CV 5/5] END algorithm=brute, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.602 total time= 2.5min
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5, weights=distance;, score=0.716 total time= 2.3min
# [CV 3/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=3, weights=uniform;, score=0.831 total time= 1.8min
# [CV 1/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=3, weights=uniform;, score=0.741 total time= 1.9min
# [CV 4/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=3, weights=uniform;, score=0.731 total time= 1.8min
# [CV 2/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=3, weights=uniform;, score=0.715 total time= 1.9min
# [CV 5/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=3, weights=uniform;, score=0.739 total time= 1.9min
# [CV 3/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=7, weights=uniform;, score=0.737 total time= 2.1min
# [CV 1/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=7, weights=uniform;, score=0.637 total time= 2.2min
# [CV 4/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=7, weights=uniform;, score=0.649 total time= 2.1min
# 7514.40s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [CV 2/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=7, weights=uniform;, score=0.644 total time= 2.2min
# [CV 5/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=7, weights=uniform;, score=0.667 total time= 2.3min
# [CV 1/5] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.714 total time= 2.5min
# [CV 2/5] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.702 total time= 2.5min
# [CV 3/5] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.759 total time= 2.4min
# [CV 4/5] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.698 total time= 2.4min
# [CV 5/5] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.684 total time= 2.4min
# 7655.96s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [CV 2/5] END algorithm=brute, leaf_size=40, n_neighbors=9, weights=distance;, score=0.677 total time= 2.4min
# [CV 1/5] END algorithm=brute, leaf_size=40, n_neighbors=9, weights=distance;, score=0.669 total time= 2.5min
# [CV 3/5] END algorithm=brute, leaf_size=40, n_neighbors=9, weights=distance;, score=0.795 total time= 2.4min
# [CV 4/5] END algorithm=brute, leaf_size=40, n_neighbors=9, weights=distance;, score=0.667 total time= 2.5min
# [CV 5/5] END algorithm=brute, leaf_size=40, n_neighbors=9, weights=distance;, score=0.676 total time= 2.4min
# [CV 2/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=4, weights=uniform;, score=0.689 total time= 2.3min
# [CV 1/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=4, weights=uniform;, score=0.715 total time= 2.4min
# [CV 3/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=4, weights=uniform;, score=0.776 total time= 2.3min
# [CV 4/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=4, weights=uniform;, score=0.682 total time= 2.3min
# 7809.86s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [CV 5/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=4, weights=uniform;, score=0.688 total time= 2.3min
# [CV 3/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=6, weights=uniform;, score=0.742 total time= 3.4min
# [CV 1/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=6, weights=uniform;, score=0.661 total time= 3.6min
# [CV 4/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=6, weights=uniform;, score=0.648 total time= 3.5min
# [CV 2/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=6, weights=uniform;, score=0.649 total time= 3.7min
# [CV 5/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=6, weights=uniform;, score=0.667 total time= 3.8min
# [CV 1/5] END algorithm=brute, leaf_size=20, n_neighbors=7, weights=distance;, score=0.716 total time= 2.4min
# [CV 2/5] END algorithm=brute, leaf_size=20, n_neighbors=7, weights=distance;, score=0.715 total time= 2.5min
# [CV 3/5] END algorithm=brute, leaf_size=20, n_neighbors=7, weights=distance;, score=0.802 total time= 2.5min
# [CV 5/5] END algorithm=brute, leaf_size=20, n_neighbors=7, weights=distance;, score=0.685 total time= 2.5min
# [CV 4/5] END algorithm=brute, leaf_size=20, n_neighbors=7, weights=distance;, score=0.689 total time= 2.5min
# [CV 1/5] END algorithm=brute, leaf_size=10, n_neighbors=7, weights=distance;, score=0.716 total time= 2.5min
# [CV 2/5] END algorithm=brute, leaf_size=10, n_neighbors=7, weights=distance;, score=0.715 total time= 2.5min
# [CV 3/5] END algorithm=brute, leaf_size=10, n_neighbors=7, weights=distance;, score=0.802 total time= 2.5min
# [CV 4/5] END algorithm=brute, leaf_size=10, n_neighbors=7, weights=distance;, score=0.689 total time= 2.5min
# [CV 5/5] END algorithm=brute, leaf_size=10, n_neighbors=7, weights=distance;, score=0.685 total time= 2.5min
# [CV 1/5] END algorithm=auto, leaf_size=10, n_neighbors=6, weights=distance;, score=0.777 total time= 2.5min
# [CV 2/5] END algorithm=auto, leaf_size=10, n_neighbors=6, weights=distance;, score=0.720 total time= 2.5min
# [CV 3/5] END algorithm=auto, leaf_size=10, n_neighbors=6, weights=distance;, score=0.818 total time= 2.5min
# [CV 4/5] END algorithm=auto, leaf_size=10, n_neighbors=6, weights=distance;, score=0.717 total time= 2.5min
# [CV 5/5] END algorithm=auto, leaf_size=10, n_neighbors=6, weights=distance;, score=0.702 total time= 2.5min
# [CV 1/5] END algorithm=auto, leaf_size=5, n_neighbors=4, weights=distance;, score=0.773 total time= 2.6min
# [CV 2/5] END algorithm=auto, leaf_size=5, n_neighbors=4, weights=distance;, score=0.744 total time= 2.6min
# [CV 3/5] END algorithm=auto, leaf_size=5, n_neighbors=4, weights=distance;, score=0.842 total time= 2.6min
# [CV 4/5] END algorithm=auto, leaf_size=5, n_neighbors=4, weights=distance;, score=0.747 total time= 2.6min
# [CV 5/5] END algorithm=auto, leaf_size=5, n_neighbors=4, weights=distance;, score=0.749 total time= 2.6min
# [CV 1/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.714 total time= 2.2min
# [CV 3/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.759 total time= 2.1min
# [CV 2/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.702 total time= 2.2min
# [CV 4/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.698 total time= 2.1min
# [CV 5/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.684 total time= 2.2min
# [CV 1/5] END algorithm=auto, leaf_size=20, n_neighbors=6, weights=distance;, score=0.777 total time= 2.4min
# [CV 2/5] END algorithm=auto, leaf_size=20, n_neighbors=6, weights=distance;, score=0.720 total time= 2.5min
# [CV 3/5] END algorithm=auto, leaf_size=20, n_neighbors=6, weights=distance;, score=0.818 total time= 2.4min
# [CV 4/5] END algorithm=auto, leaf_size=20, n_neighbors=6, weights=distance;, score=0.717 total time= 2.4min
# [CV 5/5] END algorithm=auto, leaf_size=20, n_neighbors=6, weights=distance;, score=0.702 total time= 2.4min
# [CV 2/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=6, weights=distance;, score=0.720 total time= 2.3min
# [CV 1/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=6, weights=distance;, score=0.777 total time= 2.4min
# [CV 3/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=6, weights=distance;, score=0.818 total time= 2.4min
# [CV 4/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=6, weights=distance;, score=0.717 total time= 2.4min
# [CV 5/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=6, weights=distance;, score=0.702 total time= 2.4min
# [CV 1/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=7, weights=uniform;, score=0.637 total time= 2.3min
# [CV 2/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=7, weights=uniform;, score=0.644 total time= 2.3min
# [CV 3/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=7, weights=uniform;, score=0.737 total time= 2.3min
# [CV 4/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=7, weights=uniform;, score=0.649 total time= 2.3min
# [CV 5/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=7, weights=uniform;, score=0.667 total time= 2.3min
# [CV 1/5] END algorithm=brute, leaf_size=30, n_neighbors=7, weights=distance;, score=0.716 total time= 2.4min
# [CV 2/5] END algorithm=brute, leaf_size=30, n_neighbors=7, weights=distance;, score=0.715 total time= 2.4min
# [CV 3/5] END algorithm=brute, leaf_size=30, n_neighbors=7, weights=distance;, score=0.802 total time= 2.4min
# [CV 4/5] END algorithm=brute, leaf_size=30, n_neighbors=7, weights=distance;, score=0.689 total time= 2.4min
# [CV 5/5] END algorithm=brute, leaf_size=30, n_neighbors=7, weights=distance;, score=0.685 total time= 2.4min
# [CV 1/5] END algorithm=brute, leaf_size=10, n_neighbors=9, weights=distance;, score=0.669 total time= 2.4min
# [CV 2/5] END algorithm=brute, leaf_size=10, n_neighbors=9, weights=distance;, score=0.677 total time= 2.4min
# [CV 3/5] END algorithm=brute, leaf_size=10, n_neighbors=9, weights=distance;, score=0.795 total time= 2.4min
# [CV 4/5] END algorithm=brute, leaf_size=10, n_neighbors=9, weights=distance;, score=0.667 total time= 2.4min
# [CV 5/5] END algorithm=brute, leaf_size=10, n_neighbors=9, weights=distance;, score=0.676 total time= 2.4min
# [CV 1/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=7, weights=distance;, score=0.716 total time= 2.0min
# [CV 3/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=7, weights=distance;, score=0.802 total time= 1.9min
# [CV 2/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=7, weights=distance;, score=0.715 total time= 2.1min
# [CV 4/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=7, weights=distance;, score=0.689 total time= 2.0min
# [CV 5/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=7, weights=distance;, score=0.685 total time= 2.1min
# [CV 1/5] END algorithm=auto, leaf_size=5, n_neighbors=7, weights=distance;, score=0.716 total time= 2.4min
# [CV 2/5] END algorithm=auto, leaf_size=5, n_neighbors=7, weights=distance;, score=0.715 total time= 2.4min
# [CV 3/5] END algorithm=auto, leaf_size=5, n_neighbors=7, weights=distance;, score=0.802 total time= 2.4min
# [CV 4/5] END algorithm=auto, leaf_size=5, n_neighbors=7, weights=distance;, score=0.689 total time= 2.4min
# [CV 5/5] END algorithm=auto, leaf_size=5, n_neighbors=7, weights=distance;, score=0.685 total time= 2.4min
# 8772.85s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [CV 1/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=6, weights=distance;, score=0.777 total time= 2.4min
# [CV 2/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=6, weights=distance;, score=0.720 total time= 2.3min
# [CV 3/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=6, weights=distance;, score=0.818 total time= 2.3min
# [CV 4/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=6, weights=distance;, score=0.717 total time= 2.3min
# [CV 5/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=6, weights=distance;, score=0.702 total time= 2.4min
# [CV 1/5] END algorithm=brute, leaf_size=30, n_neighbors=9, weights=uniform;, score=0.596 total time= 2.4min
# [CV 2/5] END algorithm=brute, leaf_size=30, n_neighbors=9, weights=uniform;, score=0.585 total time= 2.4min
# [CV 3/5] END algorithm=brute, leaf_size=30, n_neighbors=9, weights=uniform;, score=0.720 total time= 2.4min
# [CV 4/5] END algorithm=brute, leaf_size=30, n_neighbors=9, weights=uniform;, score=0.640 total time= 2.4min
# [CV 5/5] END algorithm=brute, leaf_size=30, n_neighbors=9, weights=uniform;, score=0.602 total time= 2.4min
# [CV 1/5] END algorithm=brute, leaf_size=30, n_neighbors=4, weights=uniform;, score=0.715 total time= 2.4min
# [CV 2/5] END algorithm=brute, leaf_size=30, n_neighbors=4, weights=uniform;, score=0.689 total time= 2.4min
# [CV 3/5] END algorithm=brute, leaf_size=30, n_neighbors=4, weights=uniform;, score=0.776 total time= 2.4min
# [CV 4/5] END algorithm=brute, leaf_size=30, n_neighbors=4, weights=uniform;, score=0.682 total time= 2.4min
# [CV 5/5] END algorithm=brute, leaf_size=30, n_neighbors=4, weights=uniform;, score=0.688 total time= 2.4min
# [CV 2/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=7, weights=distance;, score=0.715 total time= 2.4min
# [CV 1/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=7, weights=distance;, score=0.716 total time= 2.4min
# [CV 3/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=7, weights=distance;, score=0.802 total time= 2.4min
# [CV 4/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=7, weights=distance;, score=0.689 total time= 2.4min
# [CV 3/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=5, weights=distance;, score=0.816 total time= 1.9min
# [CV 1/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=5, weights=distance;, score=0.794 total time= 2.1min
# [CV 2/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=5, weights=distance;, score=0.731 total time= 2.1min
# [CV 4/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=5, weights=distance;, score=0.723 total time= 2.0min
# [CV 5/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=7, weights=distance;, score=0.685 total time= 2.4min
# [CV 5/5] END algorithm=kd_tree, leaf_size=20, n_neighbors=5, weights=distance;, score=0.716 total time= 2.2min
# [CV 1/5] END algorithm=auto, leaf_size=5, n_neighbors=6, weights=distance;, score=0.777 total time= 2.4min
# [CV 2/5] END algorithm=auto, leaf_size=5, n_neighbors=6, weights=distance;, score=0.720 total time= 2.4min
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=4, weights=uniform;, score=0.715 total time= 2.3min
# [CV 3/5] END algorithm=auto, leaf_size=5, n_neighbors=6, weights=distance;, score=0.818 total time= 2.4min
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=4, weights=uniform;, score=0.689 total time= 2.2min
# [CV 4/5] END algorithm=auto, leaf_size=5, n_neighbors=6, weights=distance;, score=0.717 total time= 2.4min
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=4, weights=uniform;, score=0.776 total time= 2.2min
# [CV 5/5] END algorithm=auto, leaf_size=5, n_neighbors=6, weights=distance;, score=0.702 total time= 2.4min
# 9188.13s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 9192.13s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=4, weights=uniform;, score=0.682 total time= 2.2min
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=4, weights=uniform;, score=0.688 total time= 2.2min
# [CV 1/5] END algorithm=auto, leaf_size=20, n_neighbors=6, weights=uniform;, score=0.661 total time= 2.4min
# [CV 2/5] END algorithm=auto, leaf_size=20, n_neighbors=6, weights=uniform;, score=0.649 total time= 2.4min
# [CV 3/5] END algorithm=auto, leaf_size=20, n_neighbors=6, weights=uniform;, score=0.742 total time= 2.4min
# [CV 4/5] END algorithm=auto, leaf_size=20, n_neighbors=6, weights=uniform;, score=0.648 total time= 2.4min
# [CV 5/5] END algorithm=auto, leaf_size=20, n_neighbors=6, weights=uniform;, score=0.667 total time= 2.4min
# [CV 1/5] END algorithm=brute, leaf_size=30, n_neighbors=6, weights=distance;, score=0.777 total time= 2.4min
# [CV 2/5] END algorithm=brute, leaf_size=30, n_neighbors=6, weights=distance;, score=0.720 total time= 2.4min
# [CV 3/5] END algorithm=brute, leaf_size=30, n_neighbors=6, weights=distance;, score=0.818 total time= 2.4min
# [CV 4/5] END algorithm=brute, leaf_size=30, n_neighbors=6, weights=distance;, score=0.717 total time= 2.4min
# [CV 5/5] END algorithm=brute, leaf_size=30, n_neighbors=6, weights=distance;, score=0.702 total time= 2.4min
# [CV 1/5] END algorithm=auto, leaf_size=40, n_neighbors=7, weights=uniform;, score=0.637 total time= 2.4min
# [CV 2/5] END algorithm=auto, leaf_size=40, n_neighbors=7, weights=uniform;, score=0.644 total time= 2.4min
# [CV 3/5] END algorithm=auto, leaf_size=40, n_neighbors=7, weights=uniform;, score=0.737 total time= 2.4min
# [CV 4/5] END algorithm=auto, leaf_size=40, n_neighbors=7, weights=uniform;, score=0.649 total time= 2.4min
# [CV 5/5] END algorithm=auto, leaf_size=40, n_neighbors=7, weights=uniform;, score=0.667 total time= 2.4min
# [CV 1/5] END algorithm=auto, leaf_size=5, n_neighbors=3, weights=distance;, score=0.761 total time= 2.4min
# [CV 2/5] END algorithm=auto, leaf_size=5, n_neighbors=3, weights=distance;, score=0.747 total time= 2.4min
# [CV 3/5] END algorithm=auto, leaf_size=5, n_neighbors=3, weights=distance;, score=0.862 total time= 2.4min
# [CV 4/5] END algorithm=auto, leaf_size=5, n_neighbors=3, weights=distance;, score=0.751 total time= 2.4min
# [CV 5/5] END algorithm=auto, leaf_size=5, n_neighbors=3, weights=distance;, score=0.763 total time= 2.4min
# [CV 2/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=4, weights=uniform;, score=0.689 total time= 2.2min
# [CV 1/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=4, weights=uniform;, score=0.715 total time= 2.3min
# [CV 3/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=4, weights=uniform;, score=0.776 total time= 2.3min
# [CV 4/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=4, weights=uniform;, score=0.682 total time= 2.3min
# [CV 5/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=4, weights=uniform;, score=0.688 total time= 2.3min
# [CV 3/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=4, weights=uniform;, score=0.776 total time= 3.0min
# [CV 1/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=4, weights=uniform;, score=0.715 total time= 3.3min
# [CV 4/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=4, weights=uniform;, score=0.682 total time= 3.2min
# [CV 2/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=4, weights=uniform;, score=0.689 total time= 3.4min
# [CV 5/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=4, weights=uniform;, score=0.688 total time= 3.4min
# [CV 1/5] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=distance;, score=0.761 total time= 2.4min
# [CV 2/5] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=distance;, score=0.747 total time= 2.4min
# [CV 3/5] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=distance;, score=0.862 total time= 2.4min
# [CV 4/5] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=distance;, score=0.751 total time= 2.4min
# ...
# [CV 3/5] END algorithm=brute, leaf_size=40, n_neighbors=5, weights=distance;, score=0.816 total time= 2.4min
# [CV 4/5] END algorithm=brute, leaf_size=40, n_neighbors=5, weights=distance;, score=0.723 total time= 2.5min
# [CV 5/5] END algorithm=brute, leaf_size=40, n_neighbors=5, weights=distance;, score=0.716 total time= 2.4min
# [CV 2/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, weights=uniform;, score=0.715 total time= 2.3min
# [CV 1/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, weights=uniform;, score=0.741 total time= 2.3min
# [CV 3/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, weights=uniform;, score=0.831 total time= 2.3min
# [CV 4/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, weights=uniform;, score=0.731 total time= 2.3min
# [CV 5/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=3, weights=uniform;, score=0.739 total time= 2.3min
# [CV 1/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=7, weights=distance;, score=0.716 total time= 2.6min
# [CV 3/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=7, weights=distance;, score=0.802 total time= 2.5min
# [CV 2/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=7, weights=distance;, score=0.715 total time= 2.7min
# 9978.99s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [CV 4/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=7, weights=distance;, score=0.689 total time= 2.5min
# 9987.64s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [CV 5/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=7, weights=distance;, score=0.685 total time= 2.7min
# [CV 1/5] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=uniform;, score=0.741 total time= 2.4min
# [CV 2/5] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=uniform;, score=0.715 total time= 2.4min
# [CV 3/5] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=uniform;, score=0.831 total time= 2.4min
# [CV 4/5] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=uniform;, score=0.731 total time= 2.4min
# [CV 5/5] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=uniform;, score=0.739 total time= 2.4min
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.714 total time= 2.3min
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.702 total time= 2.2min
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.759 total time= 2.3min
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.698 total time= 2.3min
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=5, weights=uniform;, score=0.684 total time= 2.3min
# [CV 1/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=6, weights=distance;, score=0.777 total time= 2.5min
# [CV 3/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=6, weights=distance;, score=0.818 total time= 2.4min
# [CV 2/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=6, weights=distance;, score=0.720 total time= 2.6min
# [CV 4/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=6, weights=distance;, score=0.717 total time= 2.5min
# [CV 5/5] END algorithm=kd_tree, leaf_size=10, n_neighbors=6, weights=distance;, score=0.702 total time= 2.6min
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=9, weights=distance;, score=0.669 total time= 2.4min
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=9, weights=distance;, score=0.677 total time= 2.3min
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=9, weights=distance;, score=0.795 total time= 2.4min
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=9, weights=distance;, score=0.667 total time= 2.3min
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=9, weights=distance;, score=0.676 total time= 2.4min
# [CV 1/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.596 total time= 2.4min
# [CV 2/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.585 total time= 2.3min
# [CV 3/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.720 total time= 2.4min
# [CV 4/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.640 total time= 2.4min
# [CV 5/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=9, weights=uniform;, score=0.602 total time= 2.4min
# [CV 1/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=6, weights=uniform;, score=0.661 total time= 2.4min
# [CV 2/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=6, weights=uniform;, score=0.649 total time= 2.3min
# [CV 3/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=6, weights=uniform;, score=0.742 total time= 2.4min
# [CV 4/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=6, weights=uniform;, score=0.648 total time= 2.4min
# [CV 3/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=3, weights=distance;, score=0.862 total time= 1.7min
# [CV 1/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=3, weights=distance;, score=0.761 total time= 1.8min
# [CV 5/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=6, weights=uniform;, score=0.667 total time= 2.4min
# [CV 2/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=3, weights=distance;, score=0.747 total time= 1.9min
# [CV 4/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=3, weights=distance;, score=0.751 total time= 1.8min
# [CV 5/5] END algorithm=kd_tree, leaf_size=30, n_neighbors=3, weights=distance;, score=0.763 total time= 1.9min
# 10463.29s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [CV 1/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, weights=distance;, score=0.794 total time= 2.4min
# [CV 2/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, weights=distance;, score=0.731 total time= 2.3min
# [CV 3/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, weights=distance;, score=0.816 total time= 2.3min
# [CV 4/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, weights=distance;, score=0.723 total time= 2.4min
# [CV 5/5] END algorithm=ball_tree, leaf_size=30, n_neighbors=5, weights=distance;, score=0.716 total time= 2.3min
# [CV 1/5] END algorithm=auto, leaf_size=30, n_neighbors=9, weights=distance;, score=0.669 total time= 2.4min
# [CV 2/5] END algorithm=auto, leaf_size=30, n_neighbors=9, weights=distance;, score=0.677 total time= 2.4min
# [CV 3/5] END algorithm=auto, leaf_size=30, n_neighbors=9, weights=distance;, score=0.795 total time= 2.4min
# 10582.20s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [CV 4/5] END algorithm=auto, leaf_size=30, n_neighbors=9, weights=distance;, score=0.667 total time= 2.4min
# [CV 5/5] END algorithm=auto, leaf_size=30, n_neighbors=9, weights=distance;, score=0.676 total time= 2.4min
# [CV 2/5] END algorithm=auto, leaf_size=40, n_neighbors=3, weights=distance;, score=0.747 total time= 2.4min
# [CV 1/5] END algorithm=auto, leaf_size=40, n_neighbors=3, weights=distance;, score=0.761 total time= 2.4min
# [CV 3/5] END algorithm=auto, leaf_size=40, n_neighbors=3, weights=distance;, score=0.862 total time= 2.4min
# [CV 4/5] END algorithm=auto, leaf_size=40, n_neighbors=3, weights=distance;, score=0.751 total time= 2.4min
# [CV 5/5] END algorithm=auto, leaf_size=40, n_neighbors=3, weights=distance;, score=0.763 total time= 2.4min
# [CV 1/5] END algorithm=brute, leaf_size=40, n_neighbors=4, weights=distance;, score=0.773 total time= 2.4min
# [CV 2/5] END algorithm=brute, leaf_size=40, n_neighbors=4, weights=distance;, score=0.744 total time= 2.4min
# [CV 4/5] END algorithm=brute, leaf_size=40, n_neighbors=4, weights=distance;, score=0.747 total time= 2.4min
# [CV 3/5] END algorithm=brute, leaf_size=40, n_neighbors=4, weights=distance;, score=0.842 total time= 2.4min
# [CV 5/5] END algorithm=brute, leaf_size=40, n_neighbors=4, weights=distance;, score=0.749 total time= 2.4min
# [CV 1/5] END algorithm=auto, leaf_size=10, n_neighbors=7, weights=uniform;, score=0.637 total time= 2.4min
# [CV 2/5] END algorithm=auto, leaf_size=10, n_neighbors=7, weights=uniform;, score=0.644 total time= 2.4min
# [CV 3/5] END algorithm=auto, leaf_size=10, n_neighbors=7, weights=uniform;, score=0.737 total time= 2.4min
# [CV 4/5] END algorithm=auto, leaf_size=10, n_neighbors=7, weights=uniform;, score=0.649 total time= 2.4min
# [CV 5/5] END algorithm=auto, leaf_size=10, n_neighbors=7, weights=uniform;, score=0.667 total time= 2.4min
# [CV 1/5] END algorithm=brute, leaf_size=5, n_neighbors=3, weights=uniform;, score=0.741 total time= 2.4min
# [CV 2/5] END algorithm=brute, leaf_size=5, n_neighbors=3, weights=uniform;, score=0.715 total time= 2.4min
# [CV 3/5] END algorithm=brute, leaf_size=5, n_neighbors=3, weights=uniform;, score=0.831 total time= 2.4min
# [CV 4/5] END algorithm=brute, leaf_size=5, n_neighbors=3, weights=uniform;, score=0.731 total time= 2.4min
# [CV 5/5] END algorithm=brute, leaf_size=5, n_neighbors=3, weights=uniform;, score=0.739 total time= 2.4min
# 10908.26s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [CV 2/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=7, weights=distance;, score=0.715 total time= 2.3min
# [CV 1/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=7, weights=distance;, score=0.716 total time= 2.3min
# [CV 3/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=7, weights=distance;, score=0.802 total time= 2.3min
# [CV 4/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=7, weights=distance;, score=0.689 total time= 2.3min
# [CV 5/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=7, weights=distance;, score=0.685 total time= 2.3min
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=6, weights=uniform;, score=0.649 total time= 2.3min
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=6, weights=uniform;, score=0.661 total time= 2.3min
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=6, weights=uniform;, score=0.742 total time= 2.3min
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=6, weights=uniform;, score=0.648 total time= 2.3min
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, n_neighbors=6, weights=uniform;, score=0.667 total time= 2.3min
# [CV 1/5] END algorithm=auto, leaf_size=10, n_neighbors=5, weights=distance;, score=0.794 total time= 2.4min
# [CV 2/5] END algorithm=auto, leaf_size=10, n_neighbors=5, weights=distance;, score=0.731 total time= 2.4min
# [CV 3/5] END algorithm=auto, leaf_size=10, n_neighbors=5, weights=distance;, score=0.816 total time= 2.4min
# [CV 4/5] END algorithm=auto, leaf_size=10, n_neighbors=5, weights=distance;, score=0.723 total time= 2.4min
# [CV 5/5] END algorithm=auto, leaf_size=10, n_neighbors=5, weights=distance;, score=0.716 total time= 2.4min
# [CV 3/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.720 total time= 3.6min
# [CV 1/5] END algorithm=kd_tree, leaf_size=40, n_neighbors=9, weights=distance;, score=0.669 total time= 2.1min
# [CV 4/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.640 total time= 3.7min
# [CV 1/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.596 total time= 3.8min
# [CV 2/5] END algorithm=kd_tree, leaf_size=40, n_neighbors=9, weights=distance;, score=0.677 total time= 2.1min
# [CV 3/5] END algorithm=kd_tree, leaf_size=40, n_neighbors=9, weights=distance;, score=0.795 total time= 2.0min
# 11239.60s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [CV 2/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.585 total time= 3.9min
# [CV 4/5] END algorithm=kd_tree, leaf_size=40, n_neighbors=9, weights=distance;, score=0.667 total time= 2.0min
# [CV 5/5] END algorithm=kd_tree, leaf_size=40, n_neighbors=9, weights=distance;, score=0.676 total time= 2.2min
# [CV 5/5] END algorithm=kd_tree, leaf_size=5, n_neighbors=9, weights=uniform;, score=0.602 total time= 3.9min
# [CV 2/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=6, weights=uniform;, score=0.649 total time= 2.3min
# [CV 1/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=6, weights=uniform;, score=0.661 total time= 2.4min
# [CV 3/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=6, weights=uniform;, score=0.742 total time= 2.4min
# [CV 4/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=6, weights=uniform;, score=0.648 total time= 2.4min
# [CV 5/5] END algorithm=ball_tree, leaf_size=40, n_neighbors=6, weights=uniform;, score=0.667 total time= 2.4min
# [CV 2/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=9, weights=distance;, score=0.677 total time= 2.3min
# [CV 1/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=9, weights=distance;, score=0.669 total time= 2.4min
# [CV 3/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=9, weights=distance;, score=0.795 total time= 2.3min
# [CV 4/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=9, weights=distance;, score=0.667 total time= 2.2min
# [CV 5/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=9, weights=distance;, score=0.676 total time= 2.2min
# [CV 1/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=7, weights=uniform;, score=0.637 total time= 1.7min
# [CV 2/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=7, weights=uniform;, score=0.644 total time= 1.7min
# [CV 3/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=7, weights=uniform;, score=0.737 total time= 1.7min
# [CV 4/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=7, weights=uniform;, score=0.649 total time= 1.7min
# [CV 5/5] END algorithm=ball_tree, leaf_size=5, n_neighbors=7, weights=uniform;, score=0.667 total time= 1.7min
# RandomizedSearchCV(cv=5, estimator=KNeighborsClassifier(p=1), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'algorithm': ['auto', 'ball_tree',
#                                                       'kd_tree', 'brute'],
#                                         'leaf_size': [5, 10, 20, 30, 40],
#                                         'n_neighbors': [3, 4, 5, 6, 7, 9],
#                                         'weights': ['uniform', 'distance']},
#                    random_state=61, scoring='f1', verbose=3)

# %%
# Get the best parameters
knn_random.best_params_
# Out:
# {'weights': 'distance', 'n_neighbors': 3, 'leaf_size': 30, 'algorithm': 'auto'}

# %%
# Get the best train performance
knn_random.best_score_
# Out:
# 0.7769098369167072

# %%
# Get the performance metrics
knn_best_random = knn_random.best_estimator_
knn_y_pred = knn_best_random.predict(X_test)
knn_accuracy = accuracy_score(y_test, knn_y_pred)
knn_precision = precision_score(y_test, knn_y_pred)
knn_recall = recall_score(y_test, knn_y_pred)
knn_f1 = f1_score(y_test, knn_y_pred)

print("KNN - Best Parameters:", knn_random.best_params_)
print("KNN - Accuracy:", knn_accuracy)
print("KNN - Precision:", knn_precision)
print("KNN - Recall:", knn_recall)
print("KNN - F1:", knn_f1)
# Out:
# KNN - Best Parameters: {'weights': 'distance', 'n_neighbors': 3, 'leaf_size': 30, 'algorithm': 'auto'}
# KNN - Accuracy: 0.979586129753915
# KNN - Precision: 0.8506493506493507
# KNN - Recall: 0.7237569060773481
# KNN - F1: 0.782089552238806

# %% [markdown]
# ###LSTM###

# %% [markdown]
# Without Tuning:

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import tensorflow_addons as tfa
from tensorflow.keras.metrics import Recall, Precision

# Convert DataFrame and Series to NumPy arrays
X_train_np = X_train.to_numpy()
y_train_np = np.array(y_train)

# Reshape the train data for LSTM
X_train_np = np.reshape(X_train_np, (X_train_np.shape[0], 1, X_train_np.shape[1]))

# Reshpae the test data for LSTM
X_test_np = np.reshape(X_test.to_numpy(), (X_test.to_numpy().shape[0], 1, X_test.to_numpy().shape[1]))

model = Sequential()
model.add(LSTM(64, return_sequences=True))
model.add(Dense(32, activation='tanh'))
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(16,))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[Recall(), Precision(), 'accuracy'])

# Training the model
model.fit(X_train_np, y_train_np, epochs=10, batch_size=64)

# Generate probabilities
y_pred_prob = model.predict(X_test_np, verbose=0)

# Convert probabilities into class labels
y_pred_lstm = (y_pred_prob > 0.5).astype("int32")

lstm_accuracy = accuracy_score(y_test, y_pred_lstm)
lstm_precision = precision_score(y_test, y_pred_lstm)
lstm_recall = recall_score(y_test, y_pred_lstm)
lstm_f1 = f1_score(y_test, y_pred_lstm)
# Out:
# Epoch 1/10
# 224/224 [==============================] - 3s 4ms/step - loss: 0.2400 - recall: 0.0000e+00 - precision: 0.0000e+00 - accuracy: 0.9519
# Epoch 2/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.1586 - recall: 0.0000e+00 - precision: 0.0000e+00 - accuracy: 0.9521
# Epoch 3/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.1143 - recall: 0.2628 - precision: 0.7004 - accuracy: 0.9593
# Epoch 4/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0876 - recall: 0.5533 - precision: 0.7535 - accuracy: 0.9699
# Epoch 5/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0762 - recall: 0.6423 - precision: 0.7679 - accuracy: 0.9736
# Epoch 6/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0627 - recall: 0.7124 - precision: 0.8066 - accuracy: 0.9780
# Epoch 7/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0567 - recall: 0.7328 - precision: 0.8189 - accuracy: 0.9794
# Epoch 8/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0459 - recall: 0.7942 - precision: 0.8903 - accuracy: 0.9855
# Epoch 9/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0458 - recall: 0.8029 - precision: 0.8648 - accuracy: 0.9845
# Epoch 10/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0416 - recall: 0.8015 - precision: 0.8956 - accuracy: 0.9860

# %%
# Get the performance metrics
print("LSTM - Accuracy:", lstm_accuracy)
print("LSTM - Precision:", lstm_precision)
print("LSTM - Recall:", lstm_recall)
print("LSTM - F1:", lstm_f1)
# Out:
# LSTM - Accuracy: 0.9532997762863534
# LSTM - Precision: 0.5236486486486487
# LSTM - Recall: 0.856353591160221
# LSTM - F1: 0.649895178197065

# %% [markdown]
# With Tuning:

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import tensorflow_addons as tfa
from tensorflow.keras.metrics import Recall, Precision

# Convert DataFrame and Series to NumPy arrays
X_train_np = X_train.to_numpy()
y_train_np = np.array(y_train)

# Reshape the train data for LSTM
X_train_np = np.reshape(X_train_np, (X_train_np.shape[0], 1, X_train_np.shape[1]))

# Reshpae the test data for LSTM
X_test_np = np.reshape(X_test.to_numpy(), (X_test.to_numpy().shape[0], 1, X_test.to_numpy().shape[1]))

model = Sequential()
model.add(LSTM(256, return_sequences=True))
model.add(Dense(64, activation='tanh'))
model.add(LSTM(64, return_sequences=True))
model.add(LSTM(16,))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[Recall(), Precision(), 'accuracy'])

# Training the model
model.fit(X_train_np, y_train_np, epochs=30, batch_size=64)

# Generate probabilities
y_pred_prob = model.predict(X_test_np, verbose=0)

# Convert probabilities into class labels
y_pred_lstm = (y_pred_prob > 0.5).astype("int32")

lstm_accuracy = accuracy_score(y_test, y_pred_lstm)
lstm_precision = precision_score(y_test, y_pred_lstm)
lstm_recall = recall_score(y_test, y_pred_lstm)
lstm_f1 = f1_score(y_test, y_pred_lstm)
# Out:
# Epoch 1/30
# 224/224 [==============================] - 4s 7ms/step - loss: 0.2214 - recall_25: 0.0015 - precision_25: 0.0357 - accuracy: 0.9503
# Epoch 2/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.1814 - recall_25: 0.0000e+00 - precision_25: 0.0000e+00 - accuracy: 0.9521
# Epoch 3/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.1383 - recall_25: 0.0642 - precision_25: 0.5301 - accuracy: 0.9525
# Epoch 4/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.1091 - recall_25: 0.3883 - precision_25: 0.6441 - accuracy: 0.9604
# Epoch 5/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0855 - recall_25: 0.5956 - precision_25: 0.7500 - accuracy: 0.9711
# Epoch 6/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0687 - recall_25: 0.6745 - precision_25: 0.8221 - accuracy: 0.9774
# Epoch 7/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0632 - recall_25: 0.6934 - precision_25: 0.8590 - accuracy: 0.9799
# Epoch 8/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0506 - recall_25: 0.7679 - precision_25: 0.8946 - accuracy: 0.9845
# Epoch 9/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0490 - recall_25: 0.7606 - precision_25: 0.8983 - accuracy: 0.9844
# Epoch 10/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0421 - recall_25: 0.7825 - precision_25: 0.9178 - accuracy: 0.9862
# Epoch 11/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0418 - recall_25: 0.7766 - precision_25: 0.9157 - accuracy: 0.9859
# Epoch 12/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0367 - recall_25: 0.8380 - precision_25: 0.9199 - accuracy: 0.9887
# Epoch 13/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0373 - recall_25: 0.8131 - precision_25: 0.9101 - accuracy: 0.9872
# Epoch 14/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0347 - recall_25: 0.8277 - precision_25: 0.9175 - accuracy: 0.9882
# Epoch 15/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0304 - recall_25: 0.8526 - precision_25: 0.9465 - accuracy: 0.9906
# Epoch 16/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0272 - recall_25: 0.8628 - precision_25: 0.9411 - accuracy: 0.9908
# Epoch 17/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0245 - recall_25: 0.8730 - precision_25: 0.9568 - accuracy: 0.9920
# Epoch 18/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0292 - recall_25: 0.8540 - precision_25: 0.9435 - accuracy: 0.9906
# Epoch 19/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0253 - recall_25: 0.8861 - precision_25: 0.9338 - accuracy: 0.9915
# Epoch 20/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0326 - recall_25: 0.8482 - precision_25: 0.9150 - accuracy: 0.9890
# Epoch 21/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0227 - recall_25: 0.8788 - precision_25: 0.9495 - accuracy: 0.9920
# Epoch 22/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0224 - recall_25: 0.8876 - precision_25: 0.9397 - accuracy: 0.9919
# Epoch 23/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0215 - recall_25: 0.8905 - precision_25: 0.9457 - accuracy: 0.9923
# Epoch 24/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0243 - recall_25: 0.8803 - precision_25: 0.9349 - accuracy: 0.9913
# Epoch 25/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0246 - recall_25: 0.8715 - precision_25: 0.9446 - accuracy: 0.9914
# Epoch 26/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0257 - recall_25: 0.8701 - precision_25: 0.9445 - accuracy: 0.9913
# Epoch 27/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0196 - recall_25: 0.9080 - precision_25: 0.9496 - accuracy: 0.9933
# Epoch 28/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0237 - recall_25: 0.8920 - precision_25: 0.9386 - accuracy: 0.9920
# Epoch 29/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0181 - recall_25: 0.9153 - precision_25: 0.9661 - accuracy: 0.9944
# Epoch 30/30
# 224/224 [==============================] - 2s 7ms/step - loss: 0.0158 - recall_25: 0.9197 - precision_25: 0.9737 - accuracy: 0.9950

# %%
# Get the performance metrics
print("LSTM - Accuracy:", lstm_accuracy)
print("LSTM - Precision:", lstm_precision)
print("LSTM - Recall:", lstm_recall)
print("LSTM - F1:", lstm_f1)
# Out:
# LSTM - Accuracy: 0.9823825503355704
# LSTM - Precision: 0.8277777777777777
# LSTM - Recall: 0.8232044198895028
# LSTM - F1: 0.8254847645429362
